# %% [markdown]
# ## Customer Support Ticket
#
# **Name**: Noman khan\
# Learning Data science And AI from [Codanics.com](https://codanics.com/courses/six-months-of-ai-and-data-science-mentorship-program/lesson/mastering-pandas-library-and-eda-part-5/)\
# **Mentor at Devsil**

# %% [markdown]
# ### About Dataset
# The Customer Support Ticket Dataset is a dataset that includes customer support tickets for various tech products. It consists of customer inquiries related to hardware issues, software bugs, network problems, account access, data loss, and other support topics. The dataset provides information about the customer, the product purchased, the ticket type, the ticket channel, the ticket status, and other relevant details.
#
# The dataset can be used for various analysis and modelling tasks in the customer service domain.
#
# ##### Features Description:
# * Ticket ID: A unique identifier for each ticket.
# * Customer Name: The name of the customer who raised the ticket.
# * Customer Email: The email address of the customer (Domain name - @example.com is intentional for user data privacy concern).
# * Customer Age: The age of the customer.
# * Customer Gender: The gender of the customer.
# * Product Purchased: The tech product purchased by the customer.
# * Date of Purchase: The date when the product was purchased.
# * Ticket Type: The type of ticket (e.g., technical issue, billing inquiry, product inquiry).
# * Ticket Subject: The subject/topic of the ticket.
# * Ticket Description: The description of the customer's issue or inquiry.
# * Ticket Status: The status of the ticket (e.g., open, closed, pending customer response).
# * Resolution: The resolution or solution provided for closed tickets.
# * Ticket Priority: The priority level assigned to the ticket (e.g., low, medium, high, critical).
# * Ticket Channel: The channel through which the ticket was raised (e.g., email, phone, chat, social media).
# * First Response Time: The time taken to provide the first response to the customer.
# * Time to Resolution: The time taken to resolve the ticket.
# * Customer Satisfaction Rating: The customer's satisfaction rating for closed tickets (on a scale of 1 to 5).\
# ##### Use Cases of such dataset:
# * Customer Support Analysis: The dataset can be used to analyze customer support ticket trends, identify common issues, and improve support processes.
# * Natural Language Processing (NLP): The ticket descriptions can be used for training NLP models to automate ticket categorization or sentiment analysis.
# * Customer Satisfaction Prediction: The dataset can be used to train models to predict customer satisfaction based on ticket information.
# * Ticket Resolution Time Prediction: The dataset can be used to build models for predicting the time it takes to resolve a ticket based on various factors.
# * Customer Segmentation: The dataset can be used to segment customers based on their ticket types, issues, or satisfaction levels.
# * Recommender Systems: The dataset can be used to build recommendation systems for suggesting relevant solutions or products based on customer inquiries.

# %%
# import liberaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_ind # statistical analysis

# %%
# import the data set
df=pd.read_csv('customer_support_tickets.csv')

# %%
# read the data
df.head(10)
# Out:
#    Ticket ID        Customer Name              Customer Email  Customer Age  \
# 0          1        Marisa Obrien  carrollallison@example.com            32
# 1          2         Jessica Rios    clarkeashley@example.com            42
# 2          3  Christopher Robbins   gonzalestracy@example.com            48
# 3          4     Christina Dillon    bradleyolson@example.org            27
# 4          5    Alexander Carroll     bradleymark@example.com            67
# 5          6      Rebecca Fleming     sheenasmith@example.com            53
# 6          7    Jacqueline Wright     donaldkeith@example.org            24
# 7          8           Denise Lee    joelwilliams@example.com            23
# 8          9       Nicolas Wilson        joshua24@example.com            60
# 9         10       William Dawson          clopez@example.com            27
#
#   Customer Gender        Product Purchased Date of Purchase  \
# 0           Other               GoPro Hero       2021-03-22
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8469 entries, 0 to 8468
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Ticket ID                     8469 non-null   int64
#  1   Customer Name                 8469 non-null   object
#  2   Customer Email                8469 non-null   object
#  3   Customer Age                  8469 non-null   int64
#  4   Customer Gender               8469 non-null   object
#  5   Product Purchased             8469 non-null   object
#  6   Date of Purchase              8469 non-null   object
#  7   Ticket Type                   8469 non-null   object
#  8   Ticket Subject                8469 non-null   object
#  9   Ticket Description            8469 non-null   object
#  10  Ticket Status                 8469 non-null   object
#  11  Resolution                    2769 non-null   object
# ...

# %%
df.shape
# Out:
# (8469, 17)

# %% [markdown]
# The data set contain 8469 rows and 17 columns

# %%
# checking columns name
df.columns
# Out:
# Index(['Ticket ID', 'Customer Name', 'Customer Email', 'Customer Age',
#        'Customer Gender', 'Product Purchased', 'Date of Purchase',
#        'Ticket Type', 'Ticket Subject', 'Ticket Description', 'Ticket Status',
#        'Resolution', 'Ticket Priority', 'Ticket Channel',
#        'First Response Time', 'Time to Resolution',
#        'Customer Satisfaction Rating'],
#       dtype='object')

# %%
df.describe()
# Out:
#          Ticket ID  Customer Age  Customer Satisfaction Rating
# count  8469.000000   8469.000000                   2769.000000
# mean   4235.000000     44.026804                      2.991333
# std    2444.934048     15.296112                      1.407016
# min       1.000000     18.000000                      1.000000
# 25%    2118.000000     31.000000                      2.000000
# 50%    4235.000000     44.000000                      3.000000
# 75%    6352.000000     57.000000                      4.000000
# max    8469.000000     70.000000                      5.000000

# %% [markdown]
# this show that the dataset have only three numerical columns with their descriptive statistical analysis

# %%
# now checking for null values
df.isnull().sum().sort_values(ascending=False)
# Out:
# Customer Satisfaction Rating    5700
# Resolution                      5700
# Time to Resolution              5700
# First Response Time             2819
# Ticket ID                          0
# Customer Name                      0
# Customer Email                     0
# Customer Age                       0
# Customer Gender                    0
# Ticket Subject                     0
# Ticket Type                        0
# Date of Purchase                   0
# Product Purchased                  0
# Ticket Priority                    0
# Ticket Status                      0
# Ticket Description                 0
# Ticket Channel                     0
# dtype: int64

# %%
# finding their percentage to decide which column is to be drop
missing_per=(df.isnull().sum().sort_values(ascending=False))/len(df)*100
missing_per
# Out:
# Customer Satisfaction Rating    67.304286
# Resolution                      67.304286
# Time to Resolution              67.304286
# First Response Time             33.286102
# Ticket ID                        0.000000
# Customer Name                    0.000000
# Customer Email                   0.000000
# Customer Age                     0.000000
# Customer Gender                  0.000000
# Ticket Subject                   0.000000
# Ticket Type                      0.000000
# Date of Purchase                 0.000000
# Product Purchased                0.000000
# Ticket Priority                  0.000000
# Ticket Status                    0.000000
# Ticket Description               0.000000
# Ticket Channel                   0.000000
# dtype: float64

# %%
df['Customer Satisfaction Rating'].value_counts()
# Out:
# Customer Satisfaction Rating
# 3.0    580
# 1.0    553
# 2.0    549
# 5.0    544
# 4.0    543
# Name: count, dtype: int64

# %%
# drawing bar plot of all missing values
missing_per.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# the first three column contain almost 70 percent of null values so we drop the customer satisfaction rating column because it is not as such as important and fill the the remainig three columns because they are important columns for our analysis

# %%
df.drop('Customer Satisfaction Rating',axis=1,inplace=True)

# %%
df['Resolution'].value_counts()
# Out:
# Resolution
# Case maybe show recently my computer follow.            1
# Try capital clearly never color toward story.           1
# West decision evidence bit.                             1
# Measure tonight surface feel forward.                   1
# Measure there house management pick knowledge trade.    1
#                                                        ..
# Interesting show must successful.                       1
# Skill expect admit and.                                 1
# Say position key appear behavior.                       1
# Eight account century nature kitchen.                   1
# We seat culture plan.                                   1
# Name: count, Length: 2769, dtype: int64

# %% [markdown]
# Here the column is textual and their is no standard method of filling them so we can fill all null values by a keyword 'Unknown'

# %%
df['Resolution']=df['Resolution'].fillna('unknown')
df['Resolution'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Ticket ID                 0
# Customer Name             0
# Customer Email            0
# Customer Age              0
# Customer Gender           0
# Product Purchased         0
# Date of Purchase          0
# Ticket Type               0
# Ticket Subject            0
# Ticket Description        0
# Ticket Status             0
# Resolution                0
# Ticket Priority           0
# Ticket Channel            0
# First Response Time    2819
# Time to Resolution     5700
# dtype: int64

# %% [markdown]
# # Now the data is cleaned now checking the duplicates

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
df.columns
# Out:
# Index(['Ticket ID', 'Customer Name', 'Customer Email', 'Customer Age',
#        'Customer Gender', 'Product Purchased', 'Date of Purchase',
#        'Ticket Type', 'Ticket Subject', 'Ticket Description', 'Ticket Status',
#        'Resolution', 'Ticket Priority', 'Ticket Channel',
#        'First Response Time', 'Time to Resolution'],
#       dtype='object')

# %%
df.duplicated(['Ticket ID', 'Customer Name', 'Customer Email', 'Customer Age',
       'Customer Gender', 'Product Purchased', 'Date of Purchase',
       'Ticket Type', 'Ticket Subject', 'Ticket Description', 'Ticket Status',
       'Resolution', 'Ticket Priority', 'Ticket Channel',
       'First Response Time', 'Time to Resolution']).any()
# Out:
# np.False_

# %% [markdown]
# so their is no duplicated data

# %%
# Eda (Exploratory Data analysis)

df.describe()
# Out:
#          Ticket ID  Customer Age
# count  8469.000000   8469.000000
# mean   4235.000000     44.026804
# std    2444.934048     15.296112
# min       1.000000     18.000000
# 25%    2118.000000     31.000000
# 50%    4235.000000     44.000000
# 75%    6352.000000     57.000000
# max    8469.000000     70.000000

# %%
# counting tickets by priority
df['Ticket Priority'].value_counts().sum()
# Out:
# np.int64(8469)

# %% [markdown]
# the total tickets are 8469

# %%
df['Ticket Priority'].value_counts()
# Out:
# Ticket Priority
# Medium      2192
# Critical    2129
# High        2085
# Low         2063
# Name: count, dtype: int64

# %%
# visualizing the priority through bar plot
sns.countplot(x='Ticket Priority',data=df)
plt.title('Distribution of tiket priority')
plt.xlabel('priority level')
plt.ylabel('number of ticket')
plt.show()

# %% [markdown]
# here we inter pret that the Medium level ticket have high number of range

# %%
# checking which gender has which priority level throug group by or cross table
cross_table=pd.crosstab(df['Customer Gender'],df['Ticket Priority'])
print(cross_table)
# Out:
# Ticket Priority  Critical  High  Low  Medium
# Customer Gender
# Female                727   696  724     740
# Male                  714   704  700     778
# Other                 688   685  639     674

# %%
sns.countplot(x="Customer Gender",hue='Ticket Priority',data=df)
plt.title('Priority distribution based on gender')
plt.xlabel('Gender')
plt.ylabel('Number of tickets')
plt.show()

# %% [markdown]
# now we see that the female has larger number of critical and low level priority as comared to male and male has high number of medium and high priority

# %%
# now checking the gender and their type of tiket
cross_table_type=pd.crosstab(df['Customer Gender'],df['Ticket Type'])
print(cross_table_type)
# Out:
# Ticket Type      Billing inquiry  Cancellation request  Product inquiry  \
# Customer Gender
# Female                       561                   557              554
# Male                         560                   591              558
# Other                        513                   547              529
#
# Ticket Type      Refund request  Technical issue
# Customer Gender
# Female                      617              598
# Male                        612              575
# Other                       523              574

# %%
df.dtypes
# Out:
# Ticket ID               int64
# Customer Name          object
# Customer Email         object
# Customer Age            int64
# Customer Gender        object
# Product Purchased      object
# Date of Purchase       object
# Ticket Type            object
# Ticket Subject         object
# Ticket Description     object
# Ticket Status          object
# Resolution             object
# Ticket Priority        object
# Ticket Channel         object
# First Response Time    object
# Time to Resolution     object
# dtype: object

# %%
resolved=df[df['Ticket Status']=='Closed'].groupby('Ticket Priority').size()
resolved
# Out:
# Ticket Priority
# Critical    726
# High        705
# Low         644
# Medium      694
# dtype: int64

# %% [markdown]
# here we see that the critical priority has highest number of resolve

# %%
resolved=df[df['Ticket Status']=='Closed'].groupby('Ticket Priority').size().plot(kind='bar')
plt.title('resolved ticket by priority ')
plt.xlabel('priority')
plt.ylabel('number of resolve ticket')
plt.show()

# %%
# checking the issues of customer
df['Ticket Type'].value_counts()
# Out:
# Ticket Type
# Refund request          1752
# Technical issue         1747
# Cancellation request    1695
# Product inquiry         1641
# Billing inquiry         1634
# Name: count, dtype: int64

# %% [markdown]
# by analysing the value count we see that most of the people has refund problem and billing inquiry proble is less faced by the peolpe

# %%
df['Ticket Type'].value_counts().plot(kind='bar')
plt.title('title count by issue Type')
plt.xlabel('isssue type')
plt.ylabel('Number of ticket')
plt.show()

# %%
cross_table_ip=pd.crosstab(df['Ticket Type'],df['Ticket Priority'])
cross_table_ip
# Out:
# Ticket Priority       Critical  High  Low  Medium
# Ticket Type
# Billing inquiry            420   382  398     434
# Cancellation request       423   398  414     460
# Product inquiry            403   399  398     441
# Refund request             444   448  440     420
# Technical issue            439   458  413     437

# %%
cross_table_ip.plot(kind='bar')
plt.title('issue type distribution by priority')
plt.xlabel('issue Type')
plt.ylabel('Number of Issues')
plt.show()

# %%
# Out:
# 0   2021-03-22
# 1   2021-05-22
# 2   2020-07-14
# 3   2020-11-13
# 4   2020-02-04
# Name: Date of Purchase, dtype: datetime64[ns]

# %%
# we can create new columns for easier analysis and answer question like
# 1. which month has the most tickets?
# 2. which day of the week do tickets spike?
#3. does Purchase date affect resolution time?

df['purchase_year']=df['Date of Purchase'].dt.year
df['purchased_month']=df['Date of Purchase'].dt.month
df['purchased_day']=df['Date of Purchase'].dt.day
df['purchase_weekday']=df['Date of Purchase'].dt.day_name()

# %%
df['Time to Resolution'].head()
# Out:
# 0                    NaN
# 1                    NaN
# 2    2023-06-01 18:05:38
# 3    2023-06-01 01:57:40
# 4    2023-06-01 19:53:42
# Name: Time to Resolution, dtype: object

# %% [markdown]
# here we have to derive numeric duration from the availabel timestamps

# %%
# First Convert columns to datetime
df["First Response Time"] = pd.to_datetime(df["First Response Time"])
df["Time to Resolution"] = pd.to_datetime(df["Time to Resolution"])

# Calculate duration between first response and resolution
df["Resolution_Hours"] = (df["Time to Resolution"] - df["First Response Time"]).dt.total_seconds() / 3600

# Fill NaNs if any
df["Resolution_Hours"].fillna(df["Resolution_Hours"].median(), inplace=True)

# %%
df.head(10)
# Out:
#    Ticket ID        Customer Name              Customer Email  Customer Age  \
# 0          1        Marisa Obrien  carrollallison@example.com            32
# 1          2         Jessica Rios    clarkeashley@example.com            42
# 2          3  Christopher Robbins   gonzalestracy@example.com            48
# 3          4     Christina Dillon    bradleyolson@example.org            27
# 4          5    Alexander Carroll     bradleymark@example.com            67
# 5          6      Rebecca Fleming     sheenasmith@example.com            53
# 6          7    Jacqueline Wright     donaldkeith@example.org            24
# 7          8           Denise Lee    joelwilliams@example.com            23
# 8          9       Nicolas Wilson        joshua24@example.com            60
# 9         10       William Dawson          clopez@example.com            27
#
#   Customer Gender        Product Purchased Date of Purchase  \
# 0           Other               GoPro Hero       2021-03-22
# ...

# %% [markdown]
# Taking absolute because some hours are negative this is because of the type error or incorrect data filling where the resolution time occur before the first response time

# %%
df['Resolution_Hours']=df['Resolution_Hours'].abs()

# %%
df[df['Resolution_Hours']<0].head()
# Out:
# Empty DataFrame
# Columns: [Ticket ID, Customer Name, Customer Email, Customer Age, Customer Gender, Product Purchased, Date of Purchase, Ticket Type, Ticket Subject, Ticket Description, Ticket Status, Resolution, Ticket Priority, Ticket Channel, First Response Time, Time to Resolution, Resolution_Hours]
# Index: []

# %% [markdown]
# here no . this give us a numeric hour from first response to ticket closurenegative hour left

# %%
df["Date of Purchase"] = pd.to_datetime(df["Date of Purchase"])

df["Resolution_From_Purchase_Hours"] = (df["Time to Resolution"] - df["Date of Purchase"]).dt.total_seconds() / 3600
df["Resolution_From_Purchase_Hours"]=df["Resolution_From_Purchase_Hours"].fillna(df["Resolution_From_Purchase_Hours"].median())

# %%
df.head()
# Out:
#    Ticket ID        Customer Name              Customer Email  Customer Age  \
# 0          1        Marisa Obrien  carrollallison@example.com            32
# 1          2         Jessica Rios    clarkeashley@example.com            42
# 2          3  Christopher Robbins   gonzalestracy@example.com            48
# 3          4     Christina Dillon    bradleyolson@example.org            27
# 4          5    Alexander Carroll     bradleymark@example.com            67
#
#   Customer Gender Product Purchased Date of Purchase      Ticket Type  \
# 0           Other        GoPro Hero       2021-03-22  Technical issue
# 1          Female       LG Smart TV       2021-05-22  Technical issue
# 2           Other          Dell XPS       2020-07-14  Technical issue
# 3          Female  Microsoft Office       2020-11-13  Billing inquiry
# 4          Female  Autodesk AutoCAD       2020-02-04  Billing inquiry
#
#              Ticket Subject  \
# 0             Product setup
# ...

# %% [markdown]
# This give a rough estimate of total from when the customer purcahsed the product to the ticket being resolved

# %%
# checking which gender has best resolution time or which gender problem is first solved
male_resolution=df[df['Customer Gender']=='Male']['Resolution_Hours']
female_resolution=df[df['Customer Gender']=='Female']['Resolution_Hours']
print(male_resolution.mean())
print(female_resolution.mean())
# Out:
# 2.556860036832412
# 2.605975060616557

# %%
# now checking throught histogram
plt.hist(male_resolution, bins=10, alpha=0.5, label="Male")
plt.hist(female_resolution, bins=10, alpha=0.5, label="Female")
plt.legend()
plt.xlabel("Resolution Hour")
plt.ylabel("Frequency")
plt.title("Distribution of Resolution Hour by Gender")
plt.show()

# %% [markdown]
# As their is no such difference in the Resolution time of Male and femal.

# %% [markdown]
# Let check it throuth the ttest

# %%
t_test,p_value=ttest_ind(male_resolution,female_resolution)
print("T_test: ",t_test)
print("p_value",p_value)

if p_value > 0.5:
    print("fail to reject null hypothesis, no significat difference")
else:
    print('Reject null hypothesis, their is significat difference')
# Out:
# T_test:  -0.3989536629182801
# p_value 0.6899420830773102
# fail to reject null hypothesis, no significat difference

# %% [markdown]
# now checking the priority that which prioty is resolved first or their is any difference between their mean through t_test

# %%
high_priority=df[df['Ticket Priority']=='High']['Resolution_Hours']
low_priority=df[df['Ticket Priority']=='Low']['Resolution_Hours']

print(high_priority.mean())
print(low_priority.mean())
# Out:
# 2.883285371702638
# 2.567757311358862

# %% [markdown]
# here is also no such difference but we further analyis it throuth grap and ttest

# %%
# average Resolution Time by priorigty
df.groupby('Ticket Priority')['Resolution_Hours'].mean()
# Out:
# Ticket Priority
# Critical    2.689291
# High        2.883285
# Low         2.567757
# Medium      2.442602
# Name: Resolution_Hours, dtype: float64

# %%
# checking throuth graph
plt.hist(high_priority, bins=10, alpha=0.5, label="high")
plt.hist(low_priority, bins=10, alpha=0.5, label="low")
plt.legend()
plt.xlabel("Resolution Hour")
plt.ylabel("Frequency")
plt.title("Distribution of Resolution Hour by priority")
plt.show()

# %%
# now checking the Diference through ttest
t_test,p_value=ttest_ind(high_priority,low_priority)
print("t_test: ",t_test)
print("p_value: ",p_value)

if p_value > 0.5:
    print("fail to reject null hypothesis, no significat difference")
else:
    print('Reject null hypothesis, their is significat difference')
# Out:
# t_test:  2.0580044724527418
# p_value:  0.03965207885343445
# Reject null hypothesis, their is significat difference

# %% [markdown]
# here we conclude that the priority has difference in their resolution time
# because the tTest reject the null hypothesis

# %%
# now checking which issue is most frequently occuring to know that what issue most customer Faced?
df['Ticket Type'].value_counts()
# Out:
# Ticket Type
# Refund request          1752
# Technical issue         1747
# Cancellation request    1695
# Product inquiry         1641
# Billing inquiry         1634
# Name: count, dtype: int64

# %%
# view by graph
df['Ticket Type'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# The login problem and payment problem issues is appear more frequently than other,which shows the common problem  faced by customers.

# %%
# Now  Analyzing the dat of purchase columns
df['Date of Purchase'].head()
# Out:
# 0   2021-03-22
# 1   2021-05-22
# 2   2020-07-14
# 3   2020-11-13
# 4   2020-02-04
# Name: Date of Purchase, dtype: datetime64[ns]

# %%
# we can create new columns form (date of purchase  ) for easier analysis and answer question like
# 1. which month has the most tickets?
# 2. which day of the week do tickets spike?
#3. does Purchase date affect resolution time?

df['purchase_year']=df['Date of Purchase'].dt.year
df['purchase_month']=df['Date of Purchase'].dt.month
df['purchase_day']=df['Date of Purchase'].dt.day
df['purchase_weekday']=df['Date of Purchase'].dt.day_name()

# %%
df.head()
# Out:
#    Ticket ID        Customer Name              Customer Email  Customer Age  \
# 0          1        Marisa Obrien  carrollallison@example.com            32
# 1          2         Jessica Rios    clarkeashley@example.com            42
# 2          3  Christopher Robbins   gonzalestracy@example.com            48
# 3          4     Christina Dillon    bradleyolson@example.org            27
# 4          5    Alexander Carroll     bradleymark@example.com            67
#
#   Customer Gender Product Purchased Date of Purchase      Ticket Type  \
# 0           Other        GoPro Hero       2021-03-22  Technical issue
# 1          Female       LG Smart TV       2021-05-22  Technical issue
# 2           Other          Dell XPS       2020-07-14  Technical issue
# 3          Female  Microsoft Office       2020-11-13  Billing inquiry
# 4          Female  Autodesk AutoCAD       2020-02-04  Billing inquiry
#
#              Ticket Subject  \
# 0             Product setup
# ...

# %%
# 1. which month has the most tickets?
df.groupby('purchase_month').size().plot(kind='bar')
plt.title('number of tickets by purchase Month')\

plt.xlabel('Month')
plt.ylabel('number of Tickets')
plt.show()

# %% [markdown]
# the graph clearly visualized that the 1 ,7,10 month has higher purchase
# while the 3 month has the lowest purchased.

# %%
# average time per month
df.groupby("purchase_month")["Resolution_Hours"].mean().plot(kind="bar")
plt.title("Average Resolution Time by Purchase Month")
plt.xlabel("Month")
plt.ylabel("Hours")
plt.show()

# %%
# how much ticket purchase per month?
df["purchase_weekday"].value_counts().plot(kind="bar")
plt.title("Tickets by Weekday of Purchase")
plt.show()

# %% [markdown]
# here we see that tuseday has highest purchase day

# %%
# which month has which type of issue
pd.crosstab(df['purchase_month'],df['Ticket Type']).plot(kind='bar',stacked=True)
plt.show()

# %% [markdown]
# the above graph clear show that which month has which type of issues mostly

# %%
cross_table=pd.crosstab(df['purchase_day'],['Resolution_Hours'])

# %%
cross_table
# Out:
# col_0         Resolution_Hours
# purchase_day
# 1                          283
# 2                          279
# 3                          301
# 4                          288
# 5                          288
# 6                          280
# 7                          270
# 8                          292
# 9                          284
# 10                         273
# 11                         248
# 12                         262
# 13                         290
# 14                         299
# 15                         283
# 16                         297
# 17                         277
# 18                         280
# 19                         295
# 20                         249
# 21                         306
# 22                         288
# 23                         260
# 24                         269
# 25                         288
# 26                         269
# 27                         266
# 28                         277
# ...

# %% [markdown]
# here we analyze that the 3 day of month has highest resolution hour its most of the issues are resolved on thisr day of month lets see it through a bar plot

# %%
cross_table.plot(kind='bar')
plt.show()

# %% [markdown]
# ### Finding and Conclusion
#
# **In this project**, I analyzed a customer support ticket dataset to understand how different factors such as priority level, issue type, and gender affect ticket handling and resolution. First, the dataset was cleaned by removing duplicates, handling missing values, and converting date and time columns into proper format. Since the dataset did not contain a direct column for resolution duration, I calculated the resolution time in hours by finding the difference between First Response Time and Time to Resolution. This made it possible to perform numerical and statistical analysis.
#
# **From the exploratory analysis**, it was observed that most tickets fall under the medium priority category, followed by high and low priority. Some issue types, such as login problems and payment-related issues, appear more frequently than others, which shows the common problems faced by customers. Visualizations such as bar charts and boxplots were used to better understand these patterns.
#
# **When comparing high and low priority tickets**, the average resolution time for high priority tickets was higher than that of low priority tickets. This indicates that high priority cases are usually more complex and take longer to resolve. A t-test was applied to check whether this difference was statistically significant, and the result confirmed that priority level has a significant effect on resolution time.
#
# **In addition**, first response time was compared between male and female customers. The analysis showed that both genders receive responses in almost the same amount of time. The t-test also confirmed that there is no significant difference in first response time based on gender.
#
# `Overall, this analysis shows that ticket priority plays an important role in how long it takes to resolve an issue, while gender does not have a noticeable impact on response time. These findings can help customer support teams focus more on high priority and complex issues and improve overall service quality.`
